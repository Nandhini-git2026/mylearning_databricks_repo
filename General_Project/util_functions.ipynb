# %% [markdown]
# 1. create widget without hardcoding
# 2. call config _path file take the returned string from exit as dictionary in a variable
# 3. Get SRC and BRONZE paths form config file
# 4. Spark session creation
# 5. Place the csv file in datalake volume
# 6. Read them as csv
